# %% [markdown]
# # Week 1 - Classwork

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
# Out:
# C:\Users\dell8\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %%
model.fit(xs, ys, epochs = 500)
# Out:
# Epoch 1/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 0.7227
# Epoch 2/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.6878
# Epoch 3/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.6578
# Epoch 4/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.6319
# Epoch 5/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.6091
# Epoch 6/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.5889
# Epoch 7/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.5707
# Epoch 8/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.5542
# Epoch 9/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.5391
# Epoch 10/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.5251
# Epoch 11/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.5120
# Epoch 12/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.4996
# Epoch 13/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.4879
# Epoch 14/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.4768
# Epoch 15/500
# ...

# %%
pred = np.array([10.0], dtype=float)
print(model.predict(pred))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# [[18.987064]]

# %% [markdown]
# # Assignment for Week 1 Begins

# %%
def house_model():
    
    # Define input and output tensors with the values for houses with 1 up to 6 bedrooms
    # Hint: Remember to explictly set the dtype as float
    xs = np.array([2.0, 4.0, 3.0, 5.0, 6.0, 3.0], dtype=float)
    ys = np.array([158900.0, 247560.0, 198680.0, 285478.0, 322984.0, 248945.0 ], dtype=float)
    
    # Define your model (should be a model with 1 dense layer and 1 unit)
    model = tf.keras.Sequential([keras.layers.Dense(units =1, input_shape=[1])])
    
    # Compiling the model
    # Set the optimizer to Stochastic Gradient Descent
    # and use Mean Squared Error as the loss function
    model.compile(optimizer="sgd", loss="mean_squared_error")
    
    # Train your model for 1000 epochs by feeding the i/o tensors
    model.fit(xs, ys, epochs=1000)
    
    ### END CODE HERE
    return model

# %%
# Get your trained model
model = house_model()
# Out:
# Epoch 1/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 62298619904.0000
# Epoch 2/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 27115200512.0000
# Epoch 3/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 12153224192.0000
# Epoch 4/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5789474816.0000
# Epoch 5/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3081722112.0000
# Epoch 6/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1928519296.0000
# Epoch 7/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1436321664.0000
# Epoch 8/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1225193472.0000
# Epoch 9/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1133584512.0000
# Epoch 10/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1092802944.0000
# Epoch 11/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1073641664.0000
# Epoch 12/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1063679744.0000
# Epoch 13/1000
# ...

# %%
new_y = np.array([7.0], dtype=float)
prediction = model.predict(new_y)[0]
print(prediction)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# [370333.2]
