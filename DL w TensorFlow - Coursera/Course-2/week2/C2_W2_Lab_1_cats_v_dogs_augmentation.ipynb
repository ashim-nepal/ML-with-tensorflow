# %% [markdown]
# # Ungraded Lab: Data Augmentation
#
# In the previous lessons, you saw that having a high training accuracy does not automatically mean having a good predictive model. It can still perform poorly on new data because it has overfit to the training set. In this lab, you will see how to avoid that using _data augmentation_. This increases the amount of training data by modifying the existing training data's properties. For example, in image data, you can apply different preprocessing techniques such as rotate, flip, shear, or zoom on your existing images so you can simulate other data that the model should also learn from. This way, the model would see more variety in the images during training so it will infer better on new, previously unseen data.
#
# Let's see how you can do this in the following sections.

# %% [markdown]
# ## Baseline Performance
#
# You will start with a model that's very effective at learning `Cats vs Dogs` without data augmentation. It's similar to the previous models that you have used. Note that there are four convolutional layers with 32, 64, 128 and 128 convolutions respectively. The code is basically the same from the previous lab so we won't go over the details step by step since you've already seen it before.

# %%
# First import the necessary libraries
import os
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# !wget --no-check-certificate \
    https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip \
    -O /tmp/cats_and_dogs_filtered.zip
# Out:
# --2024-08-17 04:57:51--  https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 173.194.203.207, 142.250.99.207, 74.125.199.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|173.194.203.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68606236 (65M) [application/zip]
# Saving to: ‘/tmp/cats_and_dogs_filtered.zip’
#
# /tmp/cats_and_dogs_ 100%[===================>]  65.43M   227MB/s    in 0.3s
#
# 2024-08-17 04:57:52 (227 MB/s) - ‘/tmp/cats_and_dogs_filtered.zip’ saved [68606236/68606236]

# %%
import zipfile

local_zip = '/tmp/cats_and_dogs_filtered.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()

# %%
BASE_DIR = '/tmp/cats_and_dogs_filtered'

train_dir = os.path.join(BASE_DIR, 'train')
validation_dir = os.path.join(BASE_DIR, 'validation')

# Directory with training cat/dog pictures
train_cats_dir = os.path.join(train_dir, 'cats')
train_dogs_dir = os.path.join(train_dir, 'dogs')

# Directory with validation cat/dog pictures
validation_cats_dir = os.path.join(validation_dir, 'cats')
validation_dogs_dir = os.path.join(validation_dir, 'dogs')

print(f"Contents of base directory: {os.listdir(BASE_DIR)}")

print(f"\nContents of train directory: {os.listdir(train_dir)}")

print(f"\nContents of validation directory: {os.listdir(validation_dir)}")
# Out:
# Contents of base directory: ['train', 'vectorize.py', 'validation']
#
# Contents of train directory: ['cats', 'dogs']
#
# Contents of validation directory: ['cats', 'dogs']

# %% [markdown]
# You will place the model creation inside a function so you can easily initialize a new one when you use data augmentation later in this notebook.

# %%
def create_model():
    '''Creates a CNN with 4 convolutional layers'''
    model = tf.keras.models.Sequential([
        tf.keras.Input(shape=(150, 150, 3)),
        tf.keras.layers.Rescaling(1./255),
        tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
        tf.keras.layers.MaxPooling2D(2, 2),
        tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
        tf.keras.layers.MaxPooling2D(2,2),
        tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
        tf.keras.layers.MaxPooling2D(2,2),
        tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
        tf.keras.layers.MaxPooling2D(2,2),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(512, activation='relu'),
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])

    return model

# %% [markdown]
# You will preprocess the training and validation datasets as usual.

# %%
# Instantiate the training dataset
train_dataset = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    image_size=(150, 150),
    batch_size=20,
    label_mode='binary'
    )

# Instantiate the validation dataset
validation_dataset = tf.keras.utils.image_dataset_from_directory(
    validation_dir,
    image_size=(150, 150),
    batch_size=20,
    label_mode='binary'
    )

# Optimize the datasets for training
SHUFFLE_BUFFER_SIZE = 1000
PREFETCH_BUFFER_SIZE = tf.data.AUTOTUNE

train_dataset_final = (train_dataset
                       .cache()
                       .shuffle(SHUFFLE_BUFFER_SIZE)
                       .prefetch(PREFETCH_BUFFER_SIZE)
                       )

validation_dataset_final = (validation_dataset
                            .cache()
                            .prefetch(PREFETCH_BUFFER_SIZE)
                            )
# Out:
# Found 2000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.

# %% [markdown]
# You will train only for 20 epochs to save time but feel free to increase this if you want.

# %%
# Constant for epochs
EPOCHS = 20

# Create a new model
model = create_model()

# Setup the training parameters
model.compile(loss='binary_crossentropy',
              optimizer=tf.keras.optimizers.RMSprop(learning_rate=1e-4),
              metrics=['accuracy'])

# Train the model
history = model.fit(
      train_dataset_final,
      epochs=EPOCHS,
      validation_data=validation_dataset_final,
      verbose=2)
# Out:
# Epoch 1/20
# 100/100 - 11s - 110ms/step - accuracy: 0.5170 - loss: 0.6910 - val_accuracy: 0.5000 - val_loss: 0.6912
# Epoch 2/20
# 100/100 - 2s - 15ms/step - accuracy: 0.5860 - loss: 0.6753 - val_accuracy: 0.6070 - val_loss: 0.6644
# Epoch 3/20
# 100/100 - 3s - 26ms/step - accuracy: 0.5985 - loss: 0.6605 - val_accuracy: 0.6170 - val_loss: 0.6496
# Epoch 4/20
# 100/100 - 3s - 28ms/step - accuracy: 0.6200 - loss: 0.6429 - val_accuracy: 0.6430 - val_loss: 0.6322
# Epoch 5/20
# 100/100 - 1s - 15ms/step - accuracy: 0.6560 - loss: 0.6165 - val_accuracy: 0.6590 - val_loss: 0.6153
# Epoch 6/20
# 100/100 - 1s - 15ms/step - accuracy: 0.6935 - loss: 0.5832 - val_accuracy: 0.6750 - val_loss: 0.5949
# Epoch 7/20
# 100/100 - 3s - 26ms/step - accuracy: 0.7100 - loss: 0.5574 - val_accuracy: 0.6640 - val_loss: 0.6147
# Epoch 8/20
# 100/100 - 1s - 15ms/step - accuracy: 0.7330 - loss: 0.5341 - val_accuracy: 0.7060 - val_loss: 0.5647
# Epoch 9/20
# 100/100 - 2s - 16ms/step - accuracy: 0.7485 - loss: 0.5044 - val_accuracy: 0.6860 - val_loss: 0.5922
# Epoch 10/20
# 100/100 - 1s - 15ms/step - accuracy: 0.7730 - loss: 0.4756 - val_accuracy: 0.6660 - val_loss: 0.6144
# Epoch 11/20
# 100/100 - 3s - 26ms/step - accuracy: 0.7820 - loss: 0.4605 - val_accuracy: 0.6730 - val_loss: 0.6306
# Epoch 12/20
# 100/100 - 2s - 16ms/step - accuracy: 0.8045 - loss: 0.4310 - val_accuracy: 0.7250 - val_loss: 0.5452
# Epoch 13/20
# 100/100 - 1s - 15ms/step - accuracy: 0.8230 - loss: 0.4095 - val_accuracy: 0.7350 - val_loss: 0.5338
# Epoch 14/20
# 100/100 - 3s - 25ms/step - accuracy: 0.8275 - loss: 0.3853 - val_accuracy: 0.7270 - val_loss: 0.5532
# Epoch 15/20
# 100/100 - 1s - 15ms/step - accuracy: 0.8430 - loss: 0.3638 - val_accuracy: 0.6880 - val_loss: 0.6539
# Epoch 16/20
# 100/100 - 3s - 26ms/step - accuracy: 0.8480 - loss: 0.3367 - val_accuracy: 0.7240 - val_loss: 0.5533
# Epoch 17/20
# 100/100 - 2s - 24ms/step - accuracy: 0.8670 - loss: 0.3202 - val_accuracy: 0.7160 - val_loss: 0.6213
# Epoch 18/20
# 100/100 - 1s - 15ms/step - accuracy: 0.8690 - loss: 0.3067 - val_accuracy: 0.7480 - val_loss: 0.5282
# Epoch 19/20
# 100/100 - 2s - 16ms/step - accuracy: 0.8965 - loss: 0.2703 - val_accuracy: 0.7430 - val_loss: 0.5561
# Epoch 20/20
# 100/100 - 2s - 16ms/step - accuracy: 0.8960 - loss: 0.2536 - val_accuracy: 0.7510 - val_loss: 0.5497

# %% [markdown]
# You will then visualize the loss and accuracy with respect to the training and validation set. You will again use a convenience function so it can be reused later. This function accepts a [History](https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/History) object which contains the results of the `fit()` method you ran above.

# %%
def plot_loss_acc(history):
    '''Plots the training and validation loss and accuracy from a history object'''
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(len(acc))

    fig, ax = plt.subplots(1,2, figsize=(12, 6))
    ax[0].plot(epochs, acc, 'bo', label='Training accuracy')
    ax[0].plot(epochs, val_acc, 'b', label='Validation accuracy')
    ax[0].set_title('Training and validation accuracy')
    ax[0].set_xlabel('epochs')
    ax[0].set_ylabel('accuracy')
    ax[0].legend()

    ax[1].plot(epochs, loss, 'bo', label='Training Loss')
    ax[1].plot(epochs, val_loss, 'b', label='Validation Loss')
    ax[1].set_title('Training and validation loss')
    ax[1].set_xlabel('epochs')
    ax[1].set_ylabel('loss')
    ax[1].legend()

    plt.show()

# %%
# Plot training results
plot_loss_acc(history)

# %% [markdown]
# From the results above, you'll see the training accuracy is more than 90%, and the validation accuracy is in the 70%-80% range. This is a great example of _overfitting_ -- which in short means that it can do very well with images it has seen before, but not so well with images it hasn't.

# %% [markdown]
# ## Data augmentation
#
# One simple method to avoid overfitting is to augment the images. If you think about it, most pictures of a cat are very similar -- the ears are at the top, the eyes are below the ears etc. Things like the distance between the eyes and ears will always be quite similar too.
#
# What if you tweak with the images a bit -- rotate the image, squash it, etc.  That's what image augementation is all about.
#
# To do that, you will build a data augmentation model with [preprocessing layers for image augmentation](https://www.tensorflow.org/guide/keras/preprocessing_layers#image_data_augmentation). This will transform the data during training to introduce variations of the same image. Let's quickly go over the layers you will use in this exercise.
#
# * [RandomFlip](https://www.tensorflow.org/api_docs/python/tf/keras/layers/RandomFlip) is for randomly flipping the images horizontally, vertically, or both.
# * [RandomRotation](https://www.tensorflow.org/api_docs/python/tf/keras/layers/RandomRotation) rotates the image by an angle within a given range.
# * [RandomTranslation](https://www.tensorflow.org/api_docs/python/tf/keras/layers/RandomTranslation) shifts pictures vertically and horizontally.
# * [RandomZoom](https://www.tensorflow.org/api_docs/python/tf/keras/layers/RandomZoom) zooms into or out of the images.
#
# In addition, some of these layers have a `fill_mode` parameter. This is the strategy used for filling newly created pixels, which can appear after a rotation or a width/height shift.
#
# The code below will create this model with some set parameters. After you complete this lab, feel free to modify these and see the impact on the results.

# %%
# Define fill mode.
FILL_MODE = 'nearest'

# Create the augmentation model.
data_augmentation = tf.keras.Sequential([
    # Specify the input shape.
    tf.keras.Input(shape=(150,150,3)),
    # Add the augmentation layers
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomRotation(0.2, fill_mode=FILL_MODE),
    tf.keras.layers.RandomTranslation(0.2,0.2, fill_mode=FILL_MODE),
    tf.keras.layers.RandomZoom(0.2, fill_mode=FILL_MODE)
    ])

# %% [markdown]
# You will define a utility function that lets you preview how the transformed images look like. It will take in a sample image, then output a given number of augmented images using the model you defined above.

# %%
def demo_augmentation(sample_image, model, num_aug):
    '''Takes a single image array, then uses a model to generate num_aug transformations'''

    # Instantiate preview list
    image_preview = []

    # Convert input image to a PIL image instance
    sample_image_pil = tf.keras.utils.array_to_img(sample_image)

    # Append the result to the list
    image_preview.append(sample_image_pil)

    # Apply the image augmentation and append the results to the list
    for i in range(NUM_AUG):
        sample_image_aug = model(tf.expand_dims(sample_image, axis=0))
        sample_image_aug_pil = tf.keras.utils.array_to_img(tf.squeeze(sample_image_aug))
        image_preview.append(sample_image_aug_pil)

    # Instantiate a subplot
    fig, axes = plt.subplots(1, NUM_AUG + 1, figsize=(12, 12))

    # Preview the images.
    for index, ax in enumerate(axes):
        ax.imshow(image_preview[index])
        ax.set_axis_off()

        if index == 0:
            ax.set_title('original')
        else:
            ax.set_title(f'augment {index}')

# %% [markdown]
# Now get some images from the dataset.

# %%
# Get a batch of images
sample_batch = list(train_dataset.take(1))[0][0]
print(f'images per batch: {len(sample_batch)}')
# Out:
# images per batch: 20

# %% [markdown]
# This will show sample transformations for the first 4 images of the sample batch. Notice that each call of the `data_augmentation` model yields a different output. It's like adding more images to your dataset without you having to collect them manually.

# %%
NUM_AUG = 4

# Apply the transformations to the first 4 images
demo_augmentation(sample_batch[0], data_augmentation, NUM_AUG)
demo_augmentation(sample_batch[1], data_augmentation, NUM_AUG)
demo_augmentation(sample_batch[2], data_augmentation, NUM_AUG)
demo_augmentation(sample_batch[3], data_augmentation, NUM_AUG)

# Uncomment the line below to delete the variable to free up some memory
# del sample_batch

# %% [markdown]
# Now that you see what the preprocessing layers do, you can prepend these to the base model so it can generate transformed images to the base model. Do note that these layers are only active while training. They are automatically disabled during prediction and evaluation.

# %%
# Instantiate the base model
model_without_aug = create_model()

# Prepend the data augmentation layers to the base model
model_with_aug = tf.keras.models.Sequential([
    data_augmentation,
    model_without_aug
])

# Compile the model
model_with_aug.compile(
    loss='binary_crossentropy',
    optimizer=tf.keras.optimizers.RMSprop(learning_rate=1e-4),
    metrics=['accuracy'])

# %% [markdown]
# Because you now have virtually more data, it will also take the model more time to learn the relevant features. Without data augmentation, your model already started overfitting to the training set within 20 epochs. Try training this model for 80 epochs and observe the results.

# %%
EPOCHS=80

# Train the new model
history_with_aug = model_with_aug.fit(
      train_dataset_final,
      epochs=EPOCHS,
      validation_data=validation_dataset_final,
      verbose=2)
# Out:
# Epoch 1/80
# 100/100 - 5s - 54ms/step - accuracy: 0.5150 - loss: 0.6960 - val_accuracy: 0.5010 - val_loss: 0.6933
# Epoch 2/80
# 100/100 - 2s - 20ms/step - accuracy: 0.5275 - loss: 0.6925 - val_accuracy: 0.5730 - val_loss: 0.6834
# Epoch 3/80
# 100/100 - 2s - 23ms/step - accuracy: 0.5415 - loss: 0.6865 - val_accuracy: 0.6170 - val_loss: 0.6760
# Epoch 4/80
# 100/100 - 2s - 23ms/step - accuracy: 0.5820 - loss: 0.6776 - val_accuracy: 0.5620 - val_loss: 0.6705
# Epoch 5/80
# 100/100 - 2s - 25ms/step - accuracy: 0.5865 - loss: 0.6721 - val_accuracy: 0.6230 - val_loss: 0.6462
# Epoch 6/80
# 100/100 - 3s - 25ms/step - accuracy: 0.6060 - loss: 0.6637 - val_accuracy: 0.6010 - val_loss: 0.6452
# Epoch 7/80
# 100/100 - 2s - 20ms/step - accuracy: 0.6200 - loss: 0.6457 - val_accuracy: 0.6550 - val_loss: 0.6221
# Epoch 8/80
# 100/100 - 3s - 29ms/step - accuracy: 0.6315 - loss: 0.6418 - val_accuracy: 0.6690 - val_loss: 0.6071
# Epoch 9/80
# 100/100 - 2s - 23ms/step - accuracy: 0.6230 - loss: 0.6349 - val_accuracy: 0.6900 - val_loss: 0.5964
# Epoch 10/80
# 100/100 - 2s - 20ms/step - accuracy: 0.6390 - loss: 0.6225 - val_accuracy: 0.6500 - val_loss: 0.6105
# Epoch 11/80
# 100/100 - 3s - 25ms/step - accuracy: 0.6645 - loss: 0.6218 - val_accuracy: 0.6850 - val_loss: 0.5825
# Epoch 12/80
# 100/100 - 3s - 25ms/step - accuracy: 0.6630 - loss: 0.6103 - val_accuracy: 0.5690 - val_loss: 0.6920
# Epoch 13/80
# 100/100 - 2s - 20ms/step - accuracy: 0.6705 - loss: 0.5963 - val_accuracy: 0.6910 - val_loss: 0.5675
# Epoch 14/80
# 100/100 - 3s - 26ms/step - accuracy: 0.6750 - loss: 0.6029 - val_accuracy: 0.6990 - val_loss: 0.5637
# Epoch 15/80
# 100/100 - 2s - 20ms/step - accuracy: 0.6745 - loss: 0.6010 - val_accuracy: 0.7110 - val_loss: 0.5630
# Epoch 16/80
# 100/100 - 2s - 20ms/step - accuracy: 0.6635 - loss: 0.5969 - val_accuracy: 0.7080 - val_loss: 0.5489
# Epoch 17/80
# 100/100 - 2s - 20ms/step - accuracy: 0.6735 - loss: 0.5898 - val_accuracy: 0.6820 - val_loss: 0.5713
# Epoch 18/80
# 100/100 - 3s - 25ms/step - accuracy: 0.6955 - loss: 0.5773 - val_accuracy: 0.6940 - val_loss: 0.5709
# Epoch 19/80
# 100/100 - 2s - 24ms/step - accuracy: 0.6885 - loss: 0.5879 - val_accuracy: 0.7180 - val_loss: 0.5471
# Epoch 20/80
# 100/100 - 2s - 21ms/step - accuracy: 0.7015 - loss: 0.5680 - val_accuracy: 0.7230 - val_loss: 0.5542
# Epoch 21/80
# 100/100 - 2s - 20ms/step - accuracy: 0.7115 - loss: 0.5623 - val_accuracy: 0.6900 - val_loss: 0.6144
# Epoch 22/80
# 100/100 - 2s - 20ms/step - accuracy: 0.7085 - loss: 0.5622 - val_accuracy: 0.7140 - val_loss: 0.5415
# Epoch 23/80
# 100/100 - 2s - 20ms/step - accuracy: 0.6830 - loss: 0.5724 - val_accuracy: 0.6660 - val_loss: 0.6193
# Epoch 24/80
# 100/100 - 3s - 26ms/step - accuracy: 0.6995 - loss: 0.5668 - val_accuracy: 0.7140 - val_loss: 0.5440
# Epoch 25/80
# 100/100 - 3s - 25ms/step - accuracy: 0.7105 - loss: 0.5570 - val_accuracy: 0.7160 - val_loss: 0.5458
# Epoch 26/80
# 100/100 - 2s - 20ms/step - accuracy: 0.7025 - loss: 0.5624 - val_accuracy: 0.7070 - val_loss: 0.5422
# Epoch 27/80
# 100/100 - 2s - 20ms/step - accuracy: 0.7160 - loss: 0.5539 - val_accuracy: 0.7230 - val_loss: 0.5328
# Epoch 28/80
# 100/100 - 2s - 20ms/step - accuracy: 0.7170 - loss: 0.5507 - val_accuracy: 0.7380 - val_loss: 0.5151
# Epoch 29/80
# 100/100 - 2s - 20ms/step - accuracy: 0.7050 - loss: 0.5498 - val_accuracy: 0.7400 - val_loss: 0.5122
# Epoch 30/80
# 100/100 - 3s - 26ms/step - accuracy: 0.7115 - loss: 0.5503 - val_accuracy: 0.7360 - val_loss: 0.5183
# Epoch 31/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7250 - loss: 0.5539 - val_accuracy: 0.7270 - val_loss: 0.5259
# Epoch 32/80
# 100/100 - 3s - 26ms/step - accuracy: 0.7170 - loss: 0.5476 - val_accuracy: 0.7320 - val_loss: 0.5212
# Epoch 33/80
# 100/100 - 2s - 20ms/step - accuracy: 0.7305 - loss: 0.5374 - val_accuracy: 0.7430 - val_loss: 0.5037
# Epoch 34/80
# 100/100 - 3s - 25ms/step - accuracy: 0.7345 - loss: 0.5374 - val_accuracy: 0.7240 - val_loss: 0.5212
# Epoch 35/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7270 - loss: 0.5370 - val_accuracy: 0.7270 - val_loss: 0.5277
# Epoch 36/80
# 100/100 - 2s - 21ms/step - accuracy: 0.7260 - loss: 0.5374 - val_accuracy: 0.7270 - val_loss: 0.5285
# Epoch 37/80
# 100/100 - 2s - 20ms/step - accuracy: 0.7295 - loss: 0.5369 - val_accuracy: 0.7290 - val_loss: 0.5166
# Epoch 38/80
# 100/100 - 2s - 20ms/step - accuracy: 0.7195 - loss: 0.5438 - val_accuracy: 0.7450 - val_loss: 0.5010
# Epoch 39/80
# 100/100 - 3s - 25ms/step - accuracy: 0.7300 - loss: 0.5342 - val_accuracy: 0.7100 - val_loss: 0.5574
# Epoch 40/80
# 100/100 - 3s - 26ms/step - accuracy: 0.7490 - loss: 0.5281 - val_accuracy: 0.7310 - val_loss: 0.5132
# Epoch 41/80
# 100/100 - 2s - 21ms/step - accuracy: 0.7450 - loss: 0.5128 - val_accuracy: 0.7640 - val_loss: 0.4883
# Epoch 42/80
# 100/100 - 2s - 20ms/step - accuracy: 0.7315 - loss: 0.5247 - val_accuracy: 0.7270 - val_loss: 0.5241
# Epoch 43/80
# 100/100 - 3s - 25ms/step - accuracy: 0.7440 - loss: 0.5189 - val_accuracy: 0.7590 - val_loss: 0.4869
# Epoch 44/80
# 100/100 - 2s - 20ms/step - accuracy: 0.7400 - loss: 0.5166 - val_accuracy: 0.7520 - val_loss: 0.4857
# Epoch 45/80
# 100/100 - 3s - 25ms/step - accuracy: 0.7370 - loss: 0.5185 - val_accuracy: 0.7300 - val_loss: 0.5284
# Epoch 46/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7520 - loss: 0.5090 - val_accuracy: 0.7170 - val_loss: 0.5571
# Epoch 47/80
# 100/100 - 2s - 21ms/step - accuracy: 0.7565 - loss: 0.5084 - val_accuracy: 0.7330 - val_loss: 0.5294
# Epoch 48/80
# 100/100 - 3s - 25ms/step - accuracy: 0.7465 - loss: 0.5128 - val_accuracy: 0.7460 - val_loss: 0.4926
# Epoch 49/80
# 100/100 - 2s - 20ms/step - accuracy: 0.7500 - loss: 0.5048 - val_accuracy: 0.7400 - val_loss: 0.5163
# Epoch 50/80
# 100/100 - 3s - 25ms/step - accuracy: 0.7480 - loss: 0.5094 - val_accuracy: 0.7620 - val_loss: 0.4914
# Epoch 51/80
# 100/100 - 2s - 21ms/step - accuracy: 0.7540 - loss: 0.5064 - val_accuracy: 0.7630 - val_loss: 0.4925
# Epoch 52/80
# 100/100 - 2s - 21ms/step - accuracy: 0.7445 - loss: 0.5087 - val_accuracy: 0.7550 - val_loss: 0.4890
# Epoch 53/80
# 100/100 - 2s - 20ms/step - accuracy: 0.7545 - loss: 0.4994 - val_accuracy: 0.7660 - val_loss: 0.4838
# Epoch 54/80
# 100/100 - 2s - 20ms/step - accuracy: 0.7445 - loss: 0.4992 - val_accuracy: 0.7680 - val_loss: 0.4753
# Epoch 55/80
# 100/100 - 3s - 25ms/step - accuracy: 0.7500 - loss: 0.5057 - val_accuracy: 0.7480 - val_loss: 0.4967
# Epoch 56/80
# 100/100 - 3s - 29ms/step - accuracy: 0.7625 - loss: 0.4856 - val_accuracy: 0.7450 - val_loss: 0.5111
# Epoch 57/80
# 100/100 - 2s - 21ms/step - accuracy: 0.7620 - loss: 0.4901 - val_accuracy: 0.7550 - val_loss: 0.4916
# Epoch 58/80
# 100/100 - 2s - 20ms/step - accuracy: 0.7640 - loss: 0.4943 - val_accuracy: 0.7840 - val_loss: 0.4656
# Epoch 59/80
# 100/100 - 2s - 20ms/step - accuracy: 0.7465 - loss: 0.5039 - val_accuracy: 0.7580 - val_loss: 0.4938
# Epoch 60/80
# 100/100 - 3s - 25ms/step - accuracy: 0.7665 - loss: 0.4850 - val_accuracy: 0.7790 - val_loss: 0.4662
# Epoch 61/80
# 100/100 - 2s - 20ms/step - accuracy: 0.7545 - loss: 0.4824 - val_accuracy: 0.7480 - val_loss: 0.5109
# Epoch 62/80
# 100/100 - 2s - 21ms/step - accuracy: 0.7530 - loss: 0.4932 - val_accuracy: 0.7800 - val_loss: 0.4686
# Epoch 63/80
# 100/100 - 2s - 25ms/step - accuracy: 0.7570 - loss: 0.4964 - val_accuracy: 0.7500 - val_loss: 0.5015
# Epoch 64/80
# 100/100 - 3s - 25ms/step - accuracy: 0.7595 - loss: 0.4834 - val_accuracy: 0.7630 - val_loss: 0.4900
# Epoch 65/80
# 100/100 - 3s - 25ms/step - accuracy: 0.7650 - loss: 0.4869 - val_accuracy: 0.7450 - val_loss: 0.5286
# Epoch 66/80
# 100/100 - 2s - 20ms/step - accuracy: 0.7700 - loss: 0.4793 - val_accuracy: 0.7720 - val_loss: 0.4686
# Epoch 67/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7615 - loss: 0.4875 - val_accuracy: 0.7190 - val_loss: 0.5413
# Epoch 68/80
# 100/100 - 2s - 21ms/step - accuracy: 0.7695 - loss: 0.4765 - val_accuracy: 0.7450 - val_loss: 0.5045
# Epoch 69/80
# 100/100 - 2s - 25ms/step - accuracy: 0.7755 - loss: 0.4733 - val_accuracy: 0.7690 - val_loss: 0.4686
# Epoch 70/80
# 100/100 - 3s - 25ms/step - accuracy: 0.7675 - loss: 0.4761 - val_accuracy: 0.7580 - val_loss: 0.4755
# Epoch 71/80
# 100/100 - 3s - 25ms/step - accuracy: 0.7575 - loss: 0.4841 - val_accuracy: 0.7790 - val_loss: 0.4562
# Epoch 72/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7740 - loss: 0.4714 - val_accuracy: 0.7650 - val_loss: 0.4683
# Epoch 73/80
# 100/100 - 2s - 21ms/step - accuracy: 0.7660 - loss: 0.4759 - val_accuracy: 0.7710 - val_loss: 0.4629
# Epoch 74/80
# 100/100 - 2s - 20ms/step - accuracy: 0.7705 - loss: 0.4621 - val_accuracy: 0.7720 - val_loss: 0.4746
# Epoch 75/80
# 100/100 - 2s - 20ms/step - accuracy: 0.7745 - loss: 0.4689 - val_accuracy: 0.7740 - val_loss: 0.4774
# Epoch 76/80
# 100/100 - 2s - 20ms/step - accuracy: 0.7750 - loss: 0.4750 - val_accuracy: 0.7680 - val_loss: 0.4640
# Epoch 77/80
# 100/100 - 3s - 25ms/step - accuracy: 0.7705 - loss: 0.4710 - val_accuracy: 0.7720 - val_loss: 0.4822
# Epoch 78/80
# 100/100 - 3s - 26ms/step - accuracy: 0.7835 - loss: 0.4701 - val_accuracy: 0.7670 - val_loss: 0.4870
# Epoch 79/80
# 100/100 - 2s - 20ms/step - accuracy: 0.7750 - loss: 0.4660 - val_accuracy: 0.7810 - val_loss: 0.4582
# Epoch 80/80
# 100/100 - 2s - 20ms/step - accuracy: 0.7860 - loss: 0.4625 - val_accuracy: 0.7780 - val_loss: 0.4638

# %%
# Plot the results of training with data augmentation
plot_loss_acc(history_with_aug)

# %% [markdown]
# As you can see, the training accuracy has gone down compared to the baseline. This is expected because (as a result of data augmentation) there are more variety in the images so the model will need more runs to learn from them. The good thing is the validation accuracy is no longer stalling and is more in line with the training results. This means that the model is now performing better on unseen data.

# %% [markdown]
# ## Wrap Up
#
# This exercise showed a simple trick to avoid overfitting. You can improve your baseline results by simply tweaking the same images you have already. The image augmentation preprocessing layers will do just that. Try to modify the values in the augmentation model and see what results you get. You can also add other preprocessing layers for random contrast, brightness, or cropping.
#
# Take note that this will not work for all cases. In the next lesson, Laurence will show a scenario where data augmentation will not help improve your validation accuracy.
#
# Before going back to the classroom, run the cell below to free up resources for the next lab. You might see a pop-up about restarting the kernel afterwards. You can safely ignore it and just press Ok. You can then close this lab, then go back to the classroom for the next lecture. See you there!

# %%
# Shutdown the kernel to free up resources.
# Note: You can expect a pop-up when you run this cell. You can safely ignore that and just press `Ok`.

from IPython import get_ipython

k = get_ipython().kernel

k.do_shutdown(restart=False)
